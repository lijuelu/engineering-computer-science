# %% [markdown]
# # Engineering and Computer Science
# ## Session 2. Introduction to Programming in Python

# %%
print("Hello, World!")
# Out:
# Hello, World

# %%
x = 10
y = 20

# %%
print(x==y)

# %%
print(x!=y)

# %%
age = 100

if age < 18:
    print("You are a minor.")
elif age >= 18 and age < 65:
    print("You are an adult.")
else:
    print("You are a senior citizen.")

# %%
number = 2 ** 5

if number > 500:
    print("It’s greater than 500.")
elif number > 100:
    print("It’s greater than 100 but smaller or equal to 500.")
else:
    print("It’s smaller or equal to 100.")

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print("I like", fruit)

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    if fruit == "apple":
        print("I don't like", fruit)
    else:
        print("I like", fruit)

# %%
for i in range(6):
    print(i)

# %%
for i in range(1, 6):
    print(i)

# %%
for i in range(1, 6, 2):
    print(i)

# %%
for i in range(0, 50, 10):
    print(i)

# %%
list

# %%
print(True or (False and True))

# %%
print((not False) and (True or False))

# %%
def function_name(parameters):
    # Code block
    return value  # Optional

# %%
def greet(name):
    return ("Hello, " + name + "!") # use + to combine strings

print(greet("Alice"))

# %%
sqrt(16)

# %%
from random import randint
print(randint(1, 10))

# %%
from random import *

# %%
print(randint(1, 10))

# %%
import numpy as np
arr = np.array([1, 2, 3])
print(arr)

# %%
def find_max(a, b, c):
    if a >= b and a >= c:
        return a
    elif b >= c:
        return b
    else:
        return c

# %%
find_max(2.5, 3, 4.1)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3])

# %%
import random

random.randint(1,10)

# %%
random.choice([1,2,3])

# %%
import math
print(math.sqrt(16))

# %%
def greet(name="Guest"):
    return ("Hello, " + name + "!")

print(greet())

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Alice"))

# %%
count = 5

while count > 0:
    print(count)
    count -= 1

print("Blast off!")

# %%
sum = 0
number = 1

while number <= 5:
    sum += number
    number += 1

print(sum)

# %%
import random

number_to_guess = random.randint(1, 10)
guess = 0

while guess != number_to_guess:
    guess = int(input("Guess a number between 1 and 10: "))

    if guess < number_to_guess:
        print("Too low!")
    elif guess > number_to_guess:
        print("Too high!")
    else:
        print("You guessed it!")

# %%
number = 8

if number % 2 == 1:
    print("It's an odd number")
else:
    print("It's an even number")

# %%
for i in range(1, 11):
    if i != 5:
        print(i)

# %%
import random

# %%
winning_door = random.randint(1, 3)

# %%
initial_choice = random.randint(1, 3)

# %%
doors = [1, 2, 3]

# %%
winning_door

# %%
initial_choice

# %%
doors.remove(winning_door)

# %%
doors

# %%
doors[0]

# %%
doors.remove(initial_choice)

# %%
doors.remove(winning_door, initial_choice)

# %%
doors

# %%
random.choice(doors)

# %%
import random

mylist = ["apple", "banana", "cherry"]

print(random.choice(mylist))

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)
print("winning door is", winning_door)

initial_choice = random.choice(doors)
print("initial choice is", initial_choice)

if initial_choice == winning_door:
    doors.remove(winning_door)
    print("remaining doors:", doors)
    reveal = random.choice(doors)
    print("reveal", reveal)
else:
    doors.remove(winning_door)
    doors.remove(initial_choice)
    reveal = doors[0]
    print("reveal", reveal)
#     reveal = remaining.remove(initial_choice)
#     print("reveal", reveal)

# %%
final_choice = initial_choice

# %%
final_choice

# %%
if final_choice == winning_door:
    print("Win! :)")
else:
    print("Lose :(")

# %%
reveal

# %%
doors = [1, 2, 3]
doors.remove(reveal)
print(doors)
doors.remove(initial_choice)
print(doors)
final_choise = doors[0]

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)
print("winning door is", winning_door)

initial_choice = random.choice(doors)
print("initial choice is", initial_choice)

if initial_choice == winning_door:
    # If the initial choice is the winning door, reveal one of the other two doors
    if winning_door == 1:
        reveal = random.choice([2, 3])
    elif winning_door == 2:
        reveal = random.choice([1, 3])
    else:
        reveal = random.choice([1, 2])
else:
    # If the initial choice is not the winning door, reveal the remaining door that is not the winning door or the initial choice
    for door in doors:
        if door != winning_door and door != initial_choice:
            reveal = door

print("reveal", reveal)

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)
print("winning door is", winning_door)

initial_choice = random.choice(doors)
print("initial choice is", initial_choice)

if initial_choice == winning_door:
    # Filter out the winning door and randomly select a door to reveal
    reveal = random.choice([door for door in doors if door != winning_door])
else:
    # Filter out the winning door and initial choice, then select the remaining door to reveal
    reveal = [door for door in doors if door != winning_door and door != initial_choice][0]

print("reveal", reveal)

# Filter out the revealed door and initial choice to get the final choice
doors = [door for door in doors if door != reveal and door != initial_choice]
final_choice = doors[0]
print("final choice is", final_choice)

# %%
wins = 0

for i in range(1001):

    doors = [1, 2, 3]

    winning_door = random.choice(doors)
    print("winning door is", winning_door)

    initial_choice = random.choice(doors)
    print("initial choice is", initial_choice)

    if initial_choice == winning_door:
        # Filter out the winning door and randomly select a door to reveal
        reveal = random.choice([door for door in doors if door != winning_door])
    else:
        # Filter out the winning door and initial choice, then select the remaining door to reveal
        reveal = [door for door in doors if door != winning_door and door != initial_choice][0]

    print("reveal", reveal)

    # Filter out the revealed door and initial choice to get the final choice
    doors = [door for door in doors if door != reveal and door != initial_choice]
    final_choice = doors[0]
    print("final choice is", final_choice)
    
    if final_choice == winning_door:
        wins += 1

# %% [markdown]
# # Production Code

# %% [markdown]
# ## Strategy = Not Switch

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)
print("winning door is", winning_door)

initial_choice = random.choice(doors)
print("initial choice is", initial_choice)

if initial_choice == winning_door:
    # If the initial choice is the winning door, reveal one of the other two doors
    if winning_door == 1:
        reveal = random.choice([2, 3])
    elif winning_door == 2:
        reveal = random.choice([1, 3])
    else:
        reveal = random.choice([1, 2])
else:
    # If the initial choice is not the winning door, reveal the remaining door that is not the winning door or the initial choice
    for door in doors:
        if door != winning_door and door != initial_choice:
            reveal = door

print("reveal", reveal)

final_choice = initial_choice

print("final choise is", final_choice)

if final_choice == winning_door:
    print("Win! :)")
else:
    print("Lose :(")

# %% [markdown]
# ### Loop

# %%
wins = 0

for i in range(1001):
    
    doors = [1, 2, 3]

    winning_door = random.choice(doors)

    initial_choice = random.choice(doors)

    if initial_choice == winning_door:
        # If the initial choice is the winning door, reveal one of the other two doors
        if winning_door == 1:
            reveal = random.choice([2, 3])
        elif winning_door == 2:
            reveal = random.choice([1, 3])
        else:
            reveal = random.choice([1, 2])
    else:
        # If the initial choice is not the winning door, reveal the remaining door that is not the winning door or the initial choice
        for door in doors:
            if door != winning_door and door != initial_choice:
                reveal = door

    final_choice = initial_choice

    if final_choice == winning_door:
        wins += 1
        
wins/1000

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)
print("winning door is", winning_door)

initial_choice = random.choice(doors)
print("initial choice is", initial_choice)

if initial_choice == winning_door:
    # If the initial choice is the winning door, reveal one of the other two doors
    if winning_door == 1:
        reveal = random.choice([2, 3])
    elif winning_door == 2:
        reveal = random.choice([1, 3])
    else:
        reveal = random.choice([1, 2])
else:
    # If the initial choice is not the winning door, reveal the remaining door that is not the winning door or the initial choice
    for door in doors:
        if door != winning_door and door != initial_choice:
            reveal = door

print("reveal", reveal)

final_choice = initial_choice

print("final choise is", final_choice)

if final_choice == winning_door:
    print("Win! :)")
else:
    print("Lose :(")

# %% [markdown]
# ## Strategy = Switch

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)
print("winning door is", winning_door)

initial_choice = random.choice(doors)
print("initial choice is", initial_choice)

if initial_choice == winning_door:
    # If the initial choice is the winning door, reveal one of the other two doors
    if winning_door == 1:
        reveal = random.choice([2, 3])
    elif winning_door == 2:
        reveal = random.choice([1, 3])
    else:
        reveal = random.choice([1, 2])
else:
    # If the initial choice is not the winning door, reveal the remaining door that is not the winning door or the initial choice
    for door in doors:
        if door != winning_door and door != initial_choice:
            reveal = door

print("reveal", reveal)

# Remove the revealed door and the initial choice from the list of doors 
doors.remove(initial_choice)
doors.remove(reveal)
# The remaining door is the final choice
# doors[0] = first item in the list
final_choice = doors[0]

print("final choise is", final_choice)

if final_choice == winning_door:
    print("Win! :)")
else:
    print("Lose :(")

# %% [markdown]
# ### Loop

# %%
wins = 0

for i in range(1001):
    
    doors = [1, 2, 3]

    winning_door = random.choice(doors)

    initial_choice = random.choice(doors)

    if initial_choice == winning_door:
        # If the initial choice is the winning door, reveal one of the other two doors
        if winning_door == 1:
            reveal = random.choice([2, 3])
        elif winning_door == 2:
            reveal = random.choice([1, 3])
        else:
            reveal = random.choice([1, 2])
    else:
        # If the initial choice is not the winning door, reveal the remaining door that is not the winning door or the initial choice
        for door in doors:
            if door != winning_door and door != initial_choice:
                reveal = door

    # Remove the revealed door and the initial choice from the list of doors 
    doors.remove(initial_choice)
    doors.remove(reveal)
    # The remaining door is the final choice
    # doors[0] = first item in the list
    final_choice = doors[0]

    if final_choice == winning_door:
        wins += 1

wins/1000

# %%
# Create a counter for winning times
wins = 0

# “Play” the game 1000 times – loop 1000 times
for i in range(1001):
    THE GAME
    
    if winning:
        wins += 1

wins/1000

# %% [markdown]
# # Wrap the code in a function

# %%
import random

# %%
doors_copy = doors.copy()

if initial_choice == winning_door:
    doors_copy.remove(initial_choice)
    reveal = random.choice(doors_copy)
    
else:
    doors_copy.remove(initial_choice)
    doors_copy.remove(winning_door)
    reveal = random.choice(doors_copy) # only 1 element left

# %% [markdown]
# ### Reveal the door

# %%
def reveal_door(doors, winning_door, initial_choice):
    doors_copy = doors.copy()

    if initial_choice == winning_door:
        doors_copy.remove(initial_choice)
        reveal = random.choice(doors_copy)

    else: # initial choice is not winning door
        doors_copy.remove(initial_choice)
        doors_copy.remove(winning_door)
        reveal = random.choice(doors_copy) # only 1 element left
    return(reveal)

# %% [markdown]
# ### Final choice

# %%
if switch:
    doors_copy = doors.copy()
    doors_copy.remove(initial_choice)
    doors_copy.remove(reveal)
    final_choice = random.choice(doors_copy) # only 1 element left
else:  # not switch
    final_choice = initial_choice

# %%
def get_final_choice(doors, initial_choice, reveal, switch):
    # switch: boolean True or False
    if switch:
        doors_copy = doors.copy()
        doors_copy.remove(initial_choice)
        doors_copy.remove(reveal)
        final_choice = random.choice(doors_copy) # only 1 element left
    else:  # not switch
        final_choice = initial_choice
    return(final_choice)

# %%
doors = [1, 2, 3]

winning_door = random.choice(doors)

initial_choice = random.choice(doors)

print("winning door:", winning_door)
print("initial choice:", initial_choice)

# %%
reveal = reveal_door(doors, winning_door, initial_choice)
print("reveal:", reveal)

# %%
final_choice = get_final_choice(doors, initial_choice, reveal, "switch")
print(final_choice)

# %%
final_choice = get_final_choice(doors, initial_choice, reveal, "not swithc")
print(final_choice)

# %%
def run_simulation(number_trials, switch):
    doors = [1, 2, 3]
    wins = 0
    for i in range(number_trials+1):        
        winning_door = random.choice(doors)
        initial_choice = random.choice(doors)
        
        reveal = reveal_door(doors, winning_door, initial_choice)
        
        final_choice = get_final_choice(doors, initial_choice, reveal, switch)
        
        if final_choice == winning_door:
            wins += 1
        
    percentage = wins/number_trials
    
    return(percentage)

# %%
run_simulation(1000, True)
# Out:
# 0.667

# %%
run_simulation(1000, False)
# Out:
# 0.353
